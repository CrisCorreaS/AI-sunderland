# %% [markdown]
# # Exercise 10
# **Cristina Correa - 1819211867**
#
#
# Create a text file using a notepad with a paragraph about any topic you prefer
# then read a text file using python. (Tip: to open a file in python you can use the same method
# as in week 2).

# %%
file_path = "text.txt"

with open(file_path, "r") as file:
    text = file.read()
    
print(text)
# Out:
# Jean-Michel Basquiat was an American artist, poet, musician, draughtsman, and painter known for his significant contributions to the Neo-Expressionist and Primitivist art movements.
