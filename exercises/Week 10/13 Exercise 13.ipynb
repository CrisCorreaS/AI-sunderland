# %% [markdown]
# # Exercise 13
# **Cristina Correa - 1819211867**
#
#
# Apply the Lemmatizer to the text file you opened in exercise 10

# %%
import nltk
import string

nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer


file_path = "text.txt"

with open(file_path, "r") as file:
    text = file.read()

text = text.lower()

text = text.translate(str.maketrans("", "", string.punctuation))

tokens = word_tokenize(text)

stop_words = set(stopwords.words("english"))
filtered_tokens = [word for word in tokens if word not in stop_words]


lemmatizer = WordNetLemmatizer()

print("Text Lemmatized:")
for word in filtered_tokens:
    print(f"Word: {word}, Lemma: {lemmatizer.lemmatize(word)}")
# Out:
# Text Lemmatized:
# Word: jeanmichel, Lemma: jeanmichel
# Word: basquiat, Lemma: basquiat
# Word: american, Lemma: american
# Word: artist, Lemma: artist
# Word: poet, Lemma: poet
# Word: musician, Lemma: musician
# Word: draughtsman, Lemma: draughtsman
# Word: painter, Lemma: painter
# Word: known, Lemma: known
# Word: significant, Lemma: significant
# Word: contributions, Lemma: contribution
# Word: neoexpressionist, Lemma: neoexpressionist
# Word: primitivist, Lemma: primitivist
# Word: art, Lemma: art
# Word: movements, Lemma: movement
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
