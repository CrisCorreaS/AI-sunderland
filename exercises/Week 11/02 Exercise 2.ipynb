# %% [markdown]
# # Exercise 2
# **Cristina Correa - 1819211867**
#
#
# Now try 3 different prompts and keep record of the responses.

# %%
import torch

from transformers import AutoModelForCausalLM, AutoTokenizer

# Use GPT-2 small model (smallest version)
model_name = "gpt2"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %% [markdown]
# # Example 1
# Information about Spain

# %%
# Prompt setup
prompt = "Give me a little information about Spain"

# Tokenize input prompt
model_inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generation parameters
generation_params = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}

# Generate response
generated_ids = model.generate(**model_inputs, **generation_params)

# Decode and display response
response = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(f"Response:\n{response}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response:
# Give me a little information about Spain.
#
# Spain is a country of about 1.5 million people. It is the largest economy in the world. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about 1.5 million people. It has a population of about

# %% [markdown]
# # Example 2
# Say something in Spanish

# %%
# Prompt setup
prompt = "Say something in Spanish. For example: Hola"

# Tokenize input prompt
model_inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generation parameters
generation_params = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}

# Generate response
generated_ids = model.generate(**model_inputs, **generation_params)

# Decode and display response
response = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(f"Response:\n{response}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response:
# Say something in Spanish. For example: Hola, hola, hola.
#
# Hola is a Spanish word for "to be." It is used in Spanish as a verb, and is used in English as a noun.
#
# Hola is a Spanish word for "to be." It is used in Spanish as a verb, and is used in English as a noun. Hola is a Spanish word for "to be." It is used in Spanish as a verb, and is used in English as a noun. Hola is a Spanish word for "to be." It is used in Spanish as a verb, and is used in English as a noun. Hola is a Spanish word for "to be." It is used in Spanish as a verb, and is used

# %% [markdown]
# # Example 3
# Tell me what is 2+2

# %%
# Prompt setup
prompt = "Please tell me what is the result of 2 + 2"

# Tokenize input prompt
model_inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# Generation parameters
generation_params = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}

# Generate response
generated_ids = model.generate(**model_inputs, **generation_params)

# Decode and display response
response = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(f"Response:\n{response}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Response:
# Please tell me what is the result of 2 + 2 = 2.5?
#
# I'm not sure. I think it's a bit of a stretch to say that the answer is 2.5. I think it's a bit of a stretch to say that the answer is 2.5.
#
# I think it's a bit of a stretch to say that the answer is 2.5.
#
# I think it's a bit of a stretch to say that the answer is 2.5.
#
# I think it's a bit of a stretch to say that the answer is 2.5.
#
# I think it's a bit of a stretch to say that the answer is 2.5.
#
# I think it's a bit of a stretch to say that the answer
