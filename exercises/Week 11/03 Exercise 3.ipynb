# %% [markdown]
# # Exercise 3
# **Cristina Correa - 1819211867**
#
#
# Were the answers accurate and of good quality?

# %% [markdown]
# No they where not.
#
# - In the first example it said something very wrong about the population of Spain and how we are the first economy in the world (we are not)
# - In the second example at first it said something in Spanish (hola, hola, hola) but then it said that "hola" is the verb to be in Spanish
# - In the third example it said that 2+2=2.5
