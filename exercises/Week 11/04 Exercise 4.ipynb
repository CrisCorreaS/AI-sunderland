# %% [markdown]
# # Exercise 4
# **Cristina Correa - 1819211867**
#
#
# Experiment with the model generation parameters and compare the answers.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "gpt2"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16 if torch.cuda.is_available() else torch.float32,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Give me a short introduction to large language models."

model_inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

generation_params_1 = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}
generated_ids_1 = model.generate(**model_inputs, **generation_params_1)
response_1 = tokenizer.decode(generated_ids_1[0], skip_special_tokens=True)
print(f"Original Parameters:\n{response_1}\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Original Parameters:
# Give me a short introduction to large language models.
#
# The first thing you need to know is that the language model is a set of rules that you can use to define your own language.
#
# The rules are:
#
# A language is a set of rules that you can use to define your own language.
#
# A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you

# %% [markdown]
# -------------
# # Experiment 1 - temperature=1.0

# %%
generation_params_2 = {
    "temperature": 1.0,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}
generated_ids_2 = model.generate(**model_inputs, **generation_params_2)
response_2 = tokenizer.decode(generated_ids_2[0], skip_special_tokens=True)
print(f"Experiment 1 (temperature=1.0):\n{response_2}\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Experiment 1 (temperature=1.0):
# Give me a short introduction to large language models.
#
# The first thing you need to know is that the language model is a set of rules that you can use to define your own language.
#
# The rules are:
#
# A language is a set of rules that you can use to define your own language.
#
# A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you

# %% [markdown]
# -------------
# # Experiment 2 - temperature=0.3

# %%
generation_params_3 = {
    "temperature": 0.3,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}
generated_ids_3 = model.generate(**model_inputs, **generation_params_3)
response_3 = tokenizer.decode(generated_ids_3[0], skip_special_tokens=True)
print(f"Experiment 2 (temperature=0.3):\n{response_3}\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Experiment 2 (temperature=0.3):
# Give me a short introduction to large language models.
#
# The first thing you need to know is that the language model is a set of rules that you can use to define your own language.
#
# The rules are:
#
# A language is a set of rules that you can use to define your own language.
#
# A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you

# %% [markdown]
# -------------
# # Experiment 3 - top_k=20

# %%
generation_params_4 = {
    "temperature": 0.7,
    "top_k": 20,
    "top_p": 0.9,
    "max_new_tokens": 150,
}
generated_ids_4 = model.generate(**model_inputs, **generation_params_4)
response_4 = tokenizer.decode(generated_ids_4[0], skip_special_tokens=True)
print(f"Experiment 3 (top_k=20):\n{response_4}\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Experiment 3 (top_k=20):
# Give me a short introduction to large language models.
#
# The first thing you need to know is that the language model is a set of rules that you can use to define your own language.
#
# The rules are:
#
# A language is a set of rules that you can use to define your own language.
#
# A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you

# %% [markdown]
# -------------
# # Experiment 4 - top_p=0.95

# %%
generation_params_5 = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.95,
    "max_new_tokens": 150,
}
generated_ids_5 = model.generate(**model_inputs, **generation_params_5)
response_5 = tokenizer.decode(generated_ids_5[0], skip_special_tokens=True)
print(f"Experiment 4 (top_p=0.95):\n{response_5}\n\n")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Experiment 4 (top_p=0.95):
# Give me a short introduction to large language models.
#
# The first thing you need to know is that the language model is a set of rules that you can use to define your own language.
#
# The rules are:
#
# A language is a set of rules that you can use to define your own language.
#
# A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you can use to define your own language. A language is a set of rules that you

# %% [markdown]
# While the experiments with varying temperature and top_k showed small changes, they didn't dramatically alter the repetitive output. It seems like it is fixated on the definition of "language" and repeats the same structure multiple times.
