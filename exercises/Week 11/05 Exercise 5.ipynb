# %% [markdown]
# # Exercise 5
# **Cristina Correa - 1819211867**
#
#
# Now let us try a bigger model named Qwen.

# %% [markdown]
# I had to change a little the script because it was taking more than 30 minutes to get a response

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen2.5-0.5B-Instruct"
model = AutoModelForCausalLM.from_pretrained(
    model_name, torch_dtype="auto", device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Give me a short introduction to large language models."
messages = [
    {
        "role": "system",
        "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant.",
    },
    {"role": "user", "content": prompt},
]

input_text = ""
for message in messages:
    input_text += (
        f"{message['role']}: {message['content']}\n"  # Concatenate message content
    )

model_inputs = tokenizer(input_text, return_tensors="pt").to(model.device)

generation_params = {
    "temperature": 0.7,
    "top_k": 50,
    "top_p": 0.9,
    "max_new_tokens": 150,
}

generated_ids = model.generate(**model_inputs, **generation_params)

response = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
print(f"Response:\n{response}")
# Out:
# Response:
# system: You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
# user: Give me a short introduction to large language models.
# large language models (LLMs) are artificial intelligence technologies that can generate human-like text based on the input provided. LLMs use deep learning algorithms and machine learning techniques to understand natural language, comprehend context, and produce coherent responses. They are used in various applications such as chatbots, virtual assistants, content generation, sentiment analysis, and more.
#
# Large language models have become increasingly popular over recent years due to their ability to process vast amounts of data quickly and accurately, enabling them to generate high-quality text faster than traditional approaches. They also offer flexibility and scalability, allowing users to customize their responses according to specific needs and requirements.
#
# ...
