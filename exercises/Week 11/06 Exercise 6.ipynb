# %% [markdown]
# # Exercise 6
# **Cristina Correa - 1819211867**
#
#
# Compare the answers you got from the GPT v2 model with the Qwen
# one.

# %% [markdown]
# Qwen's answer is much better because it is clear, coherent, and informative, providing a structured explanation of large language models, their functionality, applications, strengths, and challenges. It demonstrates an understanding of the topic and uses professional language, making it practical and easy to follow. In contrast, GPT-2's response is incoherent, repetitive, and doesn't have any meaningful content.
