# %% [markdown]
# # Exercise 2
# **Cristina Correa - 1819211867**
#
# Experiment with three different starting and ending points and observe the
# problem solution

# %% [markdown]
# ### First: Infinite Loop

# %%
graph = {
    "A": ["B", "E"],
    "B": ["C", "D"],
    "C": ["C"],
    "D": ["D"],
    "E": ["F", "G"],
    "F": ["F"],
    "G": ["G"],
}


def bfs(graph, start, goal):
    visited = []
    stack = [(start, [])] 

    while stack:
        node, path = stack.pop(0) 
        print(f"Current node: {node}, Path: {path + [node]}")

        if node == goal:
            return path + [node]

        if node not in visited:
            visited.append(node)

        for neighbor in graph[node]:
            stack.append((neighbor, path + [node]))

    print("Goal not found")
    return None


start_node = "E"
goal_node = "A"
result = bfs(graph, start_node, goal_node)

if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Current node: E, Path: ['E']
# Current node: F, Path: ['E', 'F']
# Current node: G, Path: ['E', 'G']
# Current node: F, Path: ['E', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G', 'G', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
# Current node: G, Path: ['E', 'G', 'G', 'G', 'G', 'G', 'G', 'G', 'G']
# Current node: F, Path: ['E', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
# ...

# %% [markdown]
# How I solved it:
# - Instead of a Last In First Out (LIFO) approach, I used a First In First Out (FIFO) approach with the deque

# %%
from collections import deque

def bfs(graph, start, goal):
    visited = set()  
    queue = deque([(start, [])])  

    while queue:
        node, path = queue.popleft()  
        print(f"Current node: {node}, Path: {path + [node]}")

        if node == goal:
            return path + [node]

        if node not in visited:
            visited.add(node)  

            for neighbor in graph[node]:
                if neighbor not in visited:
                    queue.append((neighbor, path + [node]))

    print("Goal not found")
    return None


start_node = "E"
goal_node = "A"
result = bfs(graph, start_node, goal_node)

if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Current node: E, Path: ['E']
# Current node: F, Path: ['E', 'F']
# Current node: G, Path: ['E', 'G']
# Goal not found
# No path found.

# %% [markdown]
# ### Other tries:

# %%
# Try 1

def bfs(graph, start, goal):
    visited = []
    stack = [(start, [])]

    while stack:
        node, path = stack.pop(0)
        print(f"Current node: {node}, Path: {path + [node]}")

        if node == goal:
            return path + [node]

        if node not in visited:
            visited.append(node)

        for neighbor in graph[node]:
            stack.append((neighbor, path + [node]))

    print("Goal not found")
    return None


start_node = "B"
goal_node = "D"
result = bfs(graph, start_node, goal_node)

if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Current node: B, Path: ['B']
# Current node: C, Path: ['B', 'C']
# Current node: D, Path: ['B', 'D']
# Path found: ['B', 'D']

# %%
# Try 2

def bfs(graph, start, goal):
    visited = []
    stack = [(start, [])]

    while stack:
        node, path = stack.pop(0)
        print(f"Current node: {node}, Path: {path + [node]}")

        if node == goal:
            return path + [node]

        if node not in visited:
            visited.append(node)

        for neighbor in graph[node]:
            stack.append((neighbor, path + [node]))

    print("Goal not found")
    return None


start_node = "A"
goal_node = "G"
result = bfs(graph, start_node, goal_node)

if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Current node: A, Path: ['A']
# Current node: B, Path: ['A', 'B']
# Current node: E, Path: ['A', 'E']
# Current node: C, Path: ['A', 'B', 'C']
# Current node: D, Path: ['A', 'B', 'D']
# Current node: F, Path: ['A', 'E', 'F']
# Current node: G, Path: ['A', 'E', 'G']
# Path found: ['A', 'E', 'G']

# %%
# Try 3

def bfs(graph, start, goal):
    visited = []
    stack = [(start, [])]

    while stack:
        node, path = stack.pop(0)
        print(f"Current node: {node}, Path: {path + [node]}")

        if node == goal:
            return path + [node]

        if node not in visited:
            visited.append(node)

        for neighbor in graph[node]:
            stack.append((neighbor, path + [node]))

    print("Goal not found")
    return None


start_node = "A"
goal_node = "D"
result = bfs(graph, start_node, goal_node)

if result:
    print("Path found:", result)
else:
    print("No path found.")
# Out:
# Current node: A, Path: ['A']
# Current node: B, Path: ['A', 'B']
# Current node: E, Path: ['A', 'E']
# Current node: C, Path: ['A', 'B', 'C']
# Current node: D, Path: ['A', 'B', 'D']
# Path found: ['A', 'B', 'D']
