# %% [markdown]
# # Exercise 11
# **Cristina Correa - 1819211867**
#
#
# In this exercise we will use Genetic Algorithm to find a sentence in a vector
# game. Will start with a binary exercise to guess target value code 001010

# %%
import random

# Number of individuals in each generation
POPULATION_SIZE = 4
# Valid genes
GENES = """01"""
# Target string to be generated
TARGET = "001010"

# %%
class Individual(object):
  #Class representing individual in population
  def __init__(self, chromosome):
    self.chromosome = chromosome
    self.fitness = self.cal_fitness()
  @classmethod
  def mutated_genes(self):
    #create random genes for mutation
    global GENES
    gene = random.choice(GENES)
    return gene
  @classmethod
  def create_gnome(self):
    #create chromosome or string of genes
    global TARGET
    gnome_len = len(TARGET)
    return [self.mutated_genes() for _ in range(gnome_len)]
  def mate(self, par2):
    #Perform mating and produce new offspring
    # chromosome for offspring
    child_chromosome = []
    for gp1, gp2 in zip(self.chromosome, par2.chromosome):
      # random probability
      prob = random.random()
      # if prob is less than 0.45, insert gene from parent 1
      if prob < 0.45:
        child_chromosome.append(gp1)
      # if prob is between 0.45 and 0.90, insert gene from parent 2
      elif prob < 0.90:
        child_chromosome.append(gp2)
      # otherwise insert random gene(mutate),
      # for maintaining diversity
      else:
        child_chromosome.append(self.mutated_genes())
    # create new Individual(offspring) using generated chromosome for offspring
    return Individual(child_chromosome)
  
  def cal_fitness(self):
    ''' Calculate fitness score, it is the number of characters in string
    which differ from target string. '''
    global TARGET
    fitness = 0
    for gs, gt in zip(self.chromosome, TARGET):
      if gs != gt: fitness+= 1
    return fitness

# %%
# Driver code
def main():
  global POPULATION_SIZE
  #current generation
  generation = 1
  found = False
  population = []
  # create initial population
  for _ in range(POPULATION_SIZE):
    gnome = Individual.create_gnome()
    population.append(Individual(gnome))
  while not found:
    # sort the population in increasing order of fitness score
    population = sorted(population, key = lambda x:x.fitness)
    # if the individual having lowest fitness score ie.
    # 0 then we know that we have reached to the target
    # and break the loop
    if population[0].fitness <= 0:
      found = True
      break
    # Otherwise generate new offsprings for new generation
    new_generation = []
    # Perform Elitism, that mean 10% of fittest population
    # goes to the next generation
    s = int((10*POPULATION_SIZE)/100)
    new_generation.extend(population[:s])
    # From 50% of fittest population, Individuals
    # will mate to produce offspring
    s = int((90*POPULATION_SIZE)/100)
    for _ in range(s):
      parent1 = random.choice(population[:50])
      parent2 = random.choice(population[:50])
      child = parent1.mate(parent2)
      new_generation.append(child)
    
    population = new_generation
    
    print("Generation: {}\tString: {}\tFitness: {}".format(generation, "".join(population[0].chromosome), population[0].fitness))
    generation += 1
  print("Generation: {}\tString: {}\tFitness: {}".format(generation,
    "".join(population[0].chromosome),
    population[0].fitness))
if __name__ == '__main__':
  main()
# Out:
# Generation: 1	String: 001001	Fitness: 2
# Generation: 2	String: 110001	Fitness: 5
# Generation: 3	String: 110001	Fitness: 5
# Generation: 4	String: 010101	Fitness: 5
# Generation: 5	String: 110001	Fitness: 5
# Generation: 6	String: 010101	Fitness: 5
# Generation: 7	String: 010001	Fitness: 4
# Generation: 8	String: 010001	Fitness: 4
# Generation: 9	String: 010001	Fitness: 4
# Generation: 10	String: 110001	Fitness: 5
# Generation: 11	String: 000001	Fitness: 3
# Generation: 12	String: 000001	Fitness: 3
# Generation: 13	String: 000100	Fitness: 3
# Generation: 14	String: 000101	Fitness: 4
# Generation: 15	String: 010100	Fitness: 4
# Generation: 16	String: 100100	Fitness: 4
# Generation: 17	String: 100100	Fitness: 4
# Generation: 18	String: 100111	Fitness: 4
# Generation: 19	String: 100110	Fitness: 3
# Generation: 20	String: 100110	Fitness: 3
# Generation: 21	String: 100111	Fitness: 4
# Generation: 22	String: 110110	Fitness: 4
# Generation: 23	String: 100111	Fitness: 4
# Generation: 24	String: 100011	Fitness: 3
# Generation: 25	String: 100011	Fitness: 3
# Generation: 26	String: 100000	Fitness: 3
# Generation: 27	String: 101011	Fitness: 2
# Generation: 28	String: 101001	Fitness: 3
# Generation: 29	String: 101001	Fitness: 3
# Generation: 30	String: 101101	Fitness: 4
# Generation: 31	String: 001001	Fitness: 2
# Generation: 32	String: 101101	Fitness: 4
# Generation: 33	String: 111101	Fitness: 5
# Generation: 34	String: 001101	Fitness: 3
# Generation: 35	String: 001101	Fitness: 3
# Generation: 36	String: 001000	Fitness: 1
# Generation: 37	String: 001101	Fitness: 3
# Generation: 38	String: 001101	Fitness: 3
# Generation: 39	String: 001101	Fitness: 3
# Generation: 40	String: 001100	Fitness: 2
# Generation: 41	String: 001100	Fitness: 2
# Generation: 42	String: 001100	Fitness: 2
# Generation: 43	String: 001100	Fitness: 2
# Generation: 44	String: 001001	Fitness: 2
# Generation: 45	String: 001101	Fitness: 3
# Generation: 46	String: 011001	Fitness: 3
# Generation: 47	String: 011101	Fitness: 4
# Generation: 48	String: 011000	Fitness: 2
# Generation: 49	String: 011100	Fitness: 3
# Generation: 50	String: 011100	Fitness: 3
# Generation: 51	String: 000000	Fitness: 2
# Generation: 52	String: 000000	Fitness: 2
# Generation: 53	String: 000010	Fitness: 1
# Generation: 54	String: 000001	Fitness: 3
# Generation: 55	String: 000011	Fitness: 2
# Generation: 56	String: 000011	Fitness: 2
# Generation: 57	String: 000011	Fitness: 2
# Generation: 58	String: 000011	Fitness: 2
# Generation: 59	String: 000011	Fitness: 2
# Generation: 60	String: 100101	Fitness: 5
# Generation: 61	String: 110111	Fitness: 5
# Generation: 62	String: 100111	Fitness: 4
# Generation: 63	String: 100111	Fitness: 4
# Generation: 64	String: 100111	Fitness: 4
# Generation: 65	String: 100101	Fitness: 5
# Generation: 66	String: 100100	Fitness: 4
# Generation: 67	String: 100101	Fitness: 5
# Generation: 68	String: 100100	Fitness: 4
# Generation: 69	String: 100010	Fitness: 2
# Generation: 70	String: 100111	Fitness: 4
# Generation: 71	String: 100111	Fitness: 4
# Generation: 72	String: 100000	Fitness: 3
# Generation: 73	String: 100110	Fitness: 3
# Generation: 74	String: 110010	Fitness: 3
# Generation: 75	String: 101100	Fitness: 3
# Generation: 76	String: 010100	Fitness: 4
# Generation: 77	String: 110110	Fitness: 4
# Generation: 78	String: 111110	Fitness: 3
# Generation: 79	String: 110110	Fitness: 4
# Generation: 80	String: 110110	Fitness: 4
# Generation: 81	String: 011110	Fitness: 2
# Generation: 82	String: 011110	Fitness: 2
# Generation: 83	String: 011100	Fitness: 3
# Generation: 84	String: 011101	Fitness: 4
# Generation: 85	String: 010110	Fitness: 3
# Generation: 86	String: 001111	Fitness: 2
# Generation: 87	String: 011100	Fitness: 3
# Generation: 88	String: 101100	Fitness: 3
# Generation: 89	String: 001100	Fitness: 2
# Generation: 90	String: 010100	Fitness: 4
# Generation: 91	String: 110110	Fitness: 4
# Generation: 92	String: 110110	Fitness: 4
# Generation: 93	String: 010110	Fitness: 3
# Generation: 94	String: 010110	Fitness: 3
# Generation: 95	String: 010110	Fitness: 3
# Generation: 96	String: 010110	Fitness: 3
# Generation: 97	String: 010110	Fitness: 3
# Generation: 98	String: 010110	Fitness: 3
# Generation: 99	String: 111110	Fitness: 3
# Generation: 100	String: 011110	Fitness: 2
# Generation: 101	String: 001110	Fitness: 1
# Generation: 102	String: 011110	Fitness: 2
# Generation: 103	String: 001100	Fitness: 2
# Generation: 104	String: 010100	Fitness: 4
# Generation: 105	String: 011100	Fitness: 3
# Generation: 106	String: 000100	Fitness: 3
# Generation: 107	String: 000100	Fitness: 3
# Generation: 108	String: 000000	Fitness: 2
# Generation: 109	String: 011100	Fitness: 3
# Generation: 110	String: 011100	Fitness: 3
# Generation: 111	String: 011000	Fitness: 2
# Generation: 112	String: 111000	Fitness: 3
# Generation: 113	String: 111000	Fitness: 3
# Generation: 114	String: 111010	Fitness: 2
# Generation: 115	String: 011010	Fitness: 1
# Generation: 116	String: 011010	Fitness: 1
# Generation: 117	String: 111000	Fitness: 3
# Generation: 118	String: 011010	Fitness: 1
# Generation: 119	String: 011010	Fitness: 1
# Generation: 120	String: 011010	Fitness: 1
# Generation: 121	String: 011010	Fitness: 1
# Generation: 122	String: 011010	Fitness: 1
# Generation: 123	String: 011010	Fitness: 1
# Generation: 124	String: 111010	Fitness: 2
# Generation: 125	String: 100010	Fitness: 2
# Generation: 126	String: 100111	Fitness: 4
# Generation: 127	String: 100010	Fitness: 2
# Generation: 128	String: 100010	Fitness: 2
# Generation: 129	String: 100010	Fitness: 2
# Generation: 130	String: 100000	Fitness: 3
# Generation: 131	String: 100000	Fitness: 3
# Generation: 132	String: 100001	Fitness: 4
# Generation: 133	String: 100010	Fitness: 2
# Generation: 134	String: 100001	Fitness: 4
# Generation: 135	String: 100010	Fitness: 2
# Generation: 136	String: 100001	Fitness: 4
# Generation: 137	String: 100000	Fitness: 3
# Generation: 138	String: 100001	Fitness: 4
# Generation: 139	String: 100001	Fitness: 4
# Generation: 140	String: 101001	Fitness: 3
# Generation: 141	String: 100001	Fitness: 4
# Generation: 142	String: 110011	Fitness: 4
# Generation: 143	String: 110011	Fitness: 4
# Generation: 144	String: 110001	Fitness: 5
# Generation: 145	String: 101011	Fitness: 2
# Generation: 146	String: 001011	Fitness: 1
# Generation: 147	String: 101101	Fitness: 4
# Generation: 148	String: 101101	Fitness: 4
# Generation: 149	String: 001111	Fitness: 2
# Generation: 150	String: 111111	Fitness: 4
# Generation: 151	String: 111111	Fitness: 4
# Generation: 152	String: 101000	Fitness: 2
# Generation: 153	String: 101000	Fitness: 2
# Generation: 154	String: 101000	Fitness: 2
# Generation: 155	String: 101000	Fitness: 2
# Generation: 156	String: 001000	Fitness: 1
# Generation: 157	String: 101000	Fitness: 2
# Generation: 158	String: 101000	Fitness: 2
# Generation: 159	String: 001000	Fitness: 1
# Generation: 160	String: 001000	Fitness: 1
# Generation: 161	String: 000000	Fitness: 2
# Generation: 162	String: 000100	Fitness: 3
# Generation: 163	String: 000000	Fitness: 2
# Generation: 164	String: 000000	Fitness: 2
# Generation: 165	String: 000000	Fitness: 2
# Generation: 166	String: 000000	Fitness: 2
# Generation: 167	String: 000000	Fitness: 2
# Generation: 168	String: 100000	Fitness: 3
# Generation: 169	String: 000100	Fitness: 3
# Generation: 170	String: 010001	Fitness: 4
# Generation: 171	String: 010001	Fitness: 4
# Generation: 172	String: 010001	Fitness: 4
# Generation: 173	String: 010000	Fitness: 3
# Generation: 174	String: 010000	Fitness: 3
# Generation: 175	String: 010000	Fitness: 3
# Generation: 176	String: 000001	Fitness: 3
# Generation: 177	String: 010001	Fitness: 4
# Generation: 178	String: 011001	Fitness: 3
# Generation: 179	String: 010000	Fitness: 3
# Generation: 180	String: 010001	Fitness: 4
# Generation: 181	String: 010001	Fitness: 4
# Generation: 182	String: 010001	Fitness: 4
# Generation: 183	String: 110001	Fitness: 5
# Generation: 184	String: 010001	Fitness: 4
# Generation: 185	String: 010001	Fitness: 4
# Generation: 186	String: 010001	Fitness: 4
# Generation: 187	String: 000011	Fitness: 2
# Generation: 188	String: 000110	Fitness: 2
# Generation: 189	String: 101001	Fitness: 3
# Generation: 190	String: 100011	Fitness: 3
# Generation: 191	String: 100011	Fitness: 3
# Generation: 192	String: 100011	Fitness: 3
# Generation: 193	String: 100011	Fitness: 3
# Generation: 194	String: 101011	Fitness: 2
# Generation: 195	String: 101011	Fitness: 2
# Generation: 196	String: 101111	Fitness: 3
# Generation: 197	String: 101011	Fitness: 2
# Generation: 198	String: 101011	Fitness: 2
# Generation: 199	String: 101011	Fitness: 2
# Generation: 200	String: 101011	Fitness: 2
# Generation: 201	String: 101011	Fitness: 2
# Generation: 202	String: 101001	Fitness: 3
# Generation: 203	String: 101001	Fitness: 3
# Generation: 204	String: 101011	Fitness: 2
# Generation: 205	String: 101011	Fitness: 2
# Generation: 206	String: 101001	Fitness: 3
# Generation: 207	String: 101011	Fitness: 2
# Generation: 208	String: 101001	Fitness: 3
# Generation: 209	String: 101011	Fitness: 2
# Generation: 210	String: 110011	Fitness: 4
# Generation: 211	String: 001011	Fitness: 1
# Generation: 212	String: 000011	Fitness: 2
# Generation: 213	String: 110011	Fitness: 4
# Generation: 214	String: 110011	Fitness: 4
# Generation: 215	String: 110011	Fitness: 4
# Generation: 216	String: 011011	Fitness: 2
# Generation: 217	String: 110011	Fitness: 4
# Generation: 218	String: 110011	Fitness: 4
# Generation: 219	String: 010011	Fitness: 3
# Generation: 220	String: 110110	Fitness: 4
# Generation: 221	String: 111111	Fitness: 4
# Generation: 222	String: 111111	Fitness: 4
# Generation: 223	String: 011111	Fitness: 3
# Generation: 224	String: 010011	Fitness: 3
# Generation: 225	String: 010111	Fitness: 4
# Generation: 226	String: 010010	Fitness: 2
# Generation: 227	String: 110111	Fitness: 5
# Generation: 228	String: 100111	Fitness: 4
# Generation: 229	String: 100101	Fitness: 5
# Generation: 230	String: 100111	Fitness: 4
# Generation: 231	String: 100111	Fitness: 4
# Generation: 232	String: 100101	Fitness: 5
# Generation: 233	String: 100101	Fitness: 5
# Generation: 234	String: 100101	Fitness: 5
# Generation: 235	String: 100001	Fitness: 4
# Generation: 236	String: 100011	Fitness: 3
# Generation: 237	String: 100101	Fitness: 5
# Generation: 238	String: 100111	Fitness: 4
# Generation: 239	String: 100101	Fitness: 5
# Generation: 240	String: 101011	Fitness: 2
# Generation: 241	String: 101011	Fitness: 2
# Generation: 242	String: 100111	Fitness: 4
# Generation: 243	String: 100111	Fitness: 4
# Generation: 244	String: 101011	Fitness: 2
# Generation: 245	String: 100110	Fitness: 3
# Generation: 246	String: 101011	Fitness: 2
# Generation: 247	String: 101011	Fitness: 2
# Generation: 248	String: 000011	Fitness: 2
# Generation: 249	String: 010011	Fitness: 3
# Generation: 250	String: 110110	Fitness: 4
# Generation: 251	String: 000110	Fitness: 2
# Generation: 252	String: 000010	Fitness: 1
# Generation: 253	String: 000010	Fitness: 1
# Generation: 254	String: 000010	Fitness: 1
# Generation: 255	String: 000010	Fitness: 1
# Generation: 256	String: 001010	Fitness: 0
# Generation: 257	String: 001010	Fitness: 0
