# %% [markdown]
# # Exercise 3
# **Cristina Correa - 1819211867**
#
#
# The first step of any machine learning project is to determine a problem to solve
# and find a relevant dataset that can be used to train the model. In this example let us use the
# dataset we presented in the lecture. The dataset is hosted on the UCI website, and you can
# access it via the following link:
#
# - Cortez,Paulo. (2014). Student Performance. UCI Machine Learning Repository.
# https://doi.org/10.24432/C5TG7T.
#
# Please download the dataset (in Zip format) and extract all the files in it. Inside the folder you will
# find another Zip file (named student) also Unzip it. Then copy the student-mat csv file to the
# same folder as your Jupiter notebook

# %% [markdown]
# I did it
