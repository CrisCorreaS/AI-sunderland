# %% [markdown]
# # Exercise 17
# **Cristina Correa - 1819211867**
#
#
# Compare the results you got with the results reported in the
# research paper

# %% [markdown]
# In my approach, I used a simple linear regression model with G1 as the sole predictor for G3, focusing on a single-variable analysis. I calculated metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared (R²) to evaluate the model, and visualized the results using a scatter plot with a regression line.
#
# In contrast, the paper by Cortez and Silva (2008) employed more complex models, including Decision Trees for classification tasks and Random Forests for regression, considering multiple features like demographic and school-related data. They also tackled binary classification, five-level classification, and regression tasks, using confusion matrices and scatter plots for their evaluations.
