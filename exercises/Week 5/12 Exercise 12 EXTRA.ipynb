# %% [markdown]
# # Exercise 12 EXTRA TASK
# **Cristina Correa - 1819211867**
#
#
# Read about scaling via chapter 3.3.1 of: https://www.oreilly.com/library/view/introduction-to-machine/9781449369880/ch03.html#different-kinds-of-preprocessing

# %% [markdown]
# I read about this
