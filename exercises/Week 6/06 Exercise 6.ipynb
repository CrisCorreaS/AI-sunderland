# %% [markdown]
# # Exercise 6
# **Cristina Correa - 1819211867**
#
#
# Experiment with different random state value and comment on its effect on the
# algorithm.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

random_state_value = 42

np.random.seed(random_state_value)
data, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)


def plot_kmeans_clusters(data, n_clusters, random_state_value):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="viridis", edgecolor="k", s=50)
    plt.scatter(
        kmeans.cluster_centers_[:, 0],
        kmeans.cluster_centers_[:, 1],
        c="red",
        marker="x",
        s=200,
        label="Centroids",
    )
    plt.title(f"K-means Clustering with {n_clusters} Clusters")
    plt.legend()
    plt.show()


plot_kmeans_clusters(data, n_clusters=2, random_state_value=42)
plot_kmeans_clusters(data, n_clusters=5, random_state_value=5)

# %% [markdown]
# -------------
# # Experiment 1
#
# random_state_value = 5

# %%
random_state_value = 5

np.random.seed(random_state_value)
data, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)


def plot_kmeans_clusters(data, n_clusters, random_state_value):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="viridis", edgecolor="k", s=50)
    plt.scatter(
        kmeans.cluster_centers_[:, 0],
        kmeans.cluster_centers_[:, 1],
        c="red",
        marker="x",
        s=200,
        label="Centroids",
    )
    plt.title(f"K-means Clustering with {n_clusters} Clusters")
    plt.legend()
    plt.show()


plot_kmeans_clusters(data, n_clusters=2, random_state_value=5)
plot_kmeans_clusters(data, n_clusters=5, random_state_value=5)

# %% [markdown]
# -------------
# # Experiment 2
#
# random_state_value = 100

# %%
random_state_value = 1

np.random.seed(random_state_value)
data, _ = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)


def plot_kmeans_clusters(data, n_clusters, random_state_value):
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state_value)
    labels = kmeans.fit_predict(data)
    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap="viridis", edgecolor="k", s=50)
    plt.scatter(
        kmeans.cluster_centers_[:, 0],
        kmeans.cluster_centers_[:, 1],
        c="red",
        marker="x",
        s=200,
        label="Centroids",
    )
    plt.title(f"K-means Clustering with {n_clusters} Clusters")
    plt.legend()
    plt.show()


plot_kmeans_clusters(data, n_clusters=2, random_state_value=1)
plot_kmeans_clusters(data, n_clusters=5, random_state_value=5)

# %% [markdown]
# We can see that the regular and second experiment are almost the same but the thing that is very different is in the first experiment when we see how the centroids change drastically.
