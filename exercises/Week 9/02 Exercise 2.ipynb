# %% [markdown]
# # Exercise 2
# **Cristina Correa - 1819211867**
#
#
# Download an image and save it in the same directory as the Jupiter notebook to
# use in the next few examples. You can rename the image to Image_1 to make it easier to
# use in the script. Keep a note of the file format as you will be using it in the script.

# %% [markdown]
# Okay, I downloaded an jpg image of a duck and named it Image_1
