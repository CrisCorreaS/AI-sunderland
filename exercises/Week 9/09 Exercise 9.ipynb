# %% [markdown]
# # Exercise 9
# **Cristina Correa - 1819211867**
#
#
# To work on images using the commonly used libraries such as karas we can use
# the built-in tools to do so

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import keras
from tensorflow.keras.utils import load_img

image_path = "Image_1.jpg"


# load the image
img = load_img(image_path)

# find more about the image
print(type(img))
print(img.format)
print(img.mode)
print(img.size)

# show the image
img.show()
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (980, 975)
