# %% [markdown]
# # Exercise 10
# **Cristina Correa - 1819211867**
#
#
# In the next part we will be developing an image classifier using karas. To do so
# we need to use a special type of neural network called Convolutional Neural Networks
# (CNN). Read about it in the link below: https://www.ibm.com/think/topics/convolutional-neural-networks

# %% [markdown]
# I read the article about convolutional neural networks
